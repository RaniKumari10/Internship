# %% [markdown]
# # World Happiness Report Project

# %% [markdown]
# ### Project Description

# %% [raw]
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# ### What is Dystopia?

# %% [raw]
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.

# %% [markdown]
# ### What are the residuals?

# %% [raw]
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average life evaluations. These residuals have an average value of approximately zero over the whole set of countries.

# %% [markdown]
# ### What do the columns succeeding the Happiness Score(like Family, Generosity, etc.) describe?

# %% [raw]
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.
# The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.
#
# The Dystopia Residual is already provided in the dataset.
#
# If you add all these factors up, you get the happiness score so it might be un-reliable to model them to predict Happiness Scores.
#
# You need to predict the happiness score considering all the other factors mentioned in the dataset.

# %% [markdown]
# **Dataset Link-**
#
# https://github.com/dsrscientist/DSData/blob/master/happiness_score_dataset.csv
#
# https://github.com/dsrscientist/DSData

# %% [markdown]
# ###### Importing Libaries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ###### Importing Dataset

# %%
df = pd.read_csv('Downloads/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# ###### About Data

# %% [markdown]
# **Country:** Tells us which countries were studying, helping us compare and make decisions.
#
# **Region:** Shows where countries are, so we can see trends in happiness by location.
#
# **Happiness Rank:** Ranks countries by happiness, so we know who is the happiest and set goals.
#
# **Happiness Score:** A number that shows how happy a country is, helping us see how well people are doing.
#
# **Standard Error:** Tells us how sure we can be about the happiness score, like a measure of accuracy.
#
# **Economy (GDP per Capita):** Shows how rich a country is, and how it affects happiness.
#
# **Family:** Measures how much people feel supported by their families, which is important for happiness.
#
# **Health (Life Expectancy):** Shows how long people live, which is part of being happy and helps with health decisions.
#
# **Freedom:** Tells us how free people feel, which is linked to happiness and can guide policies on personal rights.
#
# **Trust (Government Corruption):** Measures how much people trust their leaders and institutions, which can affect happiness and policy-making.
#
# **Generosity:** Measures how much people help others, giving insights into kindness and social behavior.
#
# **Dystopia Residual:** Sets a low point for happiness, so we can compare other countries against it and see how they are doing.

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.sample()
# Out:
#      Country                      Region  Happiness Rank  Happiness Score  \
# 103  Hungary  Central and Eastern Europe             104              4.8
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 103         0.06107                   1.12094  1.20215
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 103                   0.75905  0.32112                        0.02758
#
#      Generosity  Dystopia Residual
# 103       0.128            1.24074

# %% [markdown]
# ###### Exploratory Data Analysis

# %%
# Checking the dimension of dataset

df.shape
# Out:
# (158, 12)

# %% [raw]
# This dataset contains 158 rows and 12 coulmns. Out of which 1 is target variable and remaining 11 are independent variables.

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#Checking the total number of elements in dataset
df.size
# Out:
# 1896

# %%
# Checking the types of the columns

df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#Groups columns by data type

df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Happiness Rank'], float64: ['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'], object: ['Country', 'Region']}

# %% [raw]
# Here we can see that there are three types of data (int64, float and object) present in the dataset.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %% [raw]
# The dataset does not contain any duplicate data.

# %%
# Checking the null values

df.isnull()
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      False   False           False            False           False
# 1      False   False           False            False           False
# 2      False   False           False            False           False
# 3      False   False           False            False           False
# 4      False   False           False            False           False
# ..       ...     ...             ...              ...             ...
# 153    False   False           False            False           False
# 154    False   False           False            False           False
# 155    False   False           False            False           False
# 156    False   False           False            False           False
# 157    False   False           False            False           False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
# Checking the null values count in each column

df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# Visualizing the missing data with HeatMap
sns.heatmap(df.isnull(), cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <Axes: >

# %% [markdown]
# As observed in the heatmap, there is no empty spaces that indicates the absence of missing data.

# %%
#Checks for specified values in DataFrame

df.isin([' ','NA','_']).sum().any()
# Out:
# False

# %% [raw]
# There are no specified values entries within the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# The result shows that all columns have an equal number of rows, which is 158.
#
# The dataset comprises 158 rows and 12 columns.
#
# There are no instances of missing or null values in any of the dataset's columns.

# %%
df = df.rename(columns={"Happiness Rank": "Happiness_Rank", "Happiness Score": "Happiness_Score", "Standard Error": "Standard_Error", "Economy (GDP per Capita)":"Economy_GDP_per_Capita", "Health (Life Expectancy)":"Health_Life_Expectancy ", "Trust (Government Corruption)":"Trust_Government_Corruption", "Dystopia Residual": "Dystopia_Residual"  })

# %%
df.head()
# Out:
#        Country          Region  Happiness_Rank  Happiness_Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard_Error  Economy_GDP_per_Capita   Family  Health_Life_Expectancy   \
# 0         0.03411                 1.39651  1.34951                  0.94143
# 1         0.04884                 1.30232  1.40223                  0.94784
# 2         0.03328                 1.32548  1.36058                  0.87464
# 3         0.03880                 1.45900  1.33095                  0.88521
# 4         0.03553                 1.32629  1.32261                  0.90563
#
#    Freedom  Trust_Government_Corruption  Generosity  Dystopia_Residual
# ...

# %%
# Checking the group of all unique items of a column and with number of repeatation or count.
df.groupby('Region').Region.count()
# Out:
# Region
# Australia and New Zealand           2
# Central and Eastern Europe         29
# Eastern Asia                        6
# Latin America and Caribbean        22
# Middle East and Northern Africa    20
# North America                       2
# Southeastern Asia                   9
# Southern Asia                       7
# Sub-Saharan Africa                 40
# Western Europe                     21
# Name: Region, dtype: int64

# %% [markdown]
# ###### Univariant Analysis

# %%
#Univariant Analysis
sns.set_style("white")
plt.figure(figsize=(10,5))
ax = sns.countplot(x='Region', data=df)
ax.set_xticklabels(ax.get_xticklabels(), horizontalalignment='right', rotation=45)

plt.show()
#None  #don't show the label objects

# %% [raw]
# Here we can see that Region with high and low count.

# %%
#Bivariant Analysis
plt.figure(figsize=(8,4), facecolor='pink')
ax=sns.scatterplot(x = 'Happiness_Score', y = 'Economy_GDP_per_Capita', hue = 'Region', data=df)
ax.set_title('Relationship Between Happiness_Score and Economy_GDP_per_Capita by Region')
plt.legend(loc = 'upper left', fontsize = '8')
plt.show()

# %%
gdp_region = df.groupby('Region')['Economy_GDP_per_Capita'].sum()
gdp_region
# Out:
# Region
# Australia and New Zealand           2.58376
# Central and Eastern Europe         27.33071
# Eastern Asia                        6.91068
# Latin America and Caribbean        19.28994
# Middle East and Northern Africa    21.33947
# North America                       2.72080
# Southeastern Asia                   7.10149
# Southern Asia                       3.92340
# Sub-Saharan Africa                 15.21892
# Western Europe                     27.27051
# Name: Economy_GDP_per_Capita, dtype: float64

# %%
labels = df.groupby('Region').groups
gdp_region = df.groupby('Region')['Economy_GDP_per_Capita'].sum() 
fig, ax = plt.subplots(figsize=(5.5, 5.5), facecolor='lavenderblush')
# Create the pie chart with equal aspect ratio and centered position
ax.pie(gdp_region, labels=labels, radius=0.5, autopct='%1.8f%%', shadow=False, startangle=90)
ax.axis('equal')  
ax.set_title('GDP Distribution by Region') 

# Show the plot
plt.show()

# %% [raw]
# These values represent the total economic output per countries within each respective region.

# %%
df.head()
# Out:
#        Country          Region  Happiness_Rank  Happiness_Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard_Error  Economy_GDP_per_Capita   Family  Health_Life_Expectancy   \
# 0         0.03411                 1.39651  1.34951                  0.94143
# 1         0.04884                 1.30232  1.40223                  0.94784
# 2         0.03328                 1.32548  1.36058                  0.87464
# 3         0.03880                 1.45900  1.33095                  0.88521
# 4         0.03553                 1.32629  1.32261                  0.90563
#
#    Freedom  Trust_Government_Corruption  Generosity  Dystopia_Residual
# ...

# %%
sns.lmplot(x='Trust_Government_Corruption',y='Standard_Error',data=df)
plt.show()

# %% [raw]
# Trust_Government_Corruption has a negative correlation with Standard_Error.

# %%
sns.lmplot(x='Happiness_Score',y='Dystopia_Residual',data=df)
plt.show()

# %% [raw]
# Happiness_Score has a positive correlation with Dystopia_Residual.

# %%
sns.lmplot(x='Happiness_Score',y='Generosity',data=df)
plt.show()

# %% [raw]
# Generosity has somewhat of a positive linear association with Happiness_Score.

# %%
sns.lmplot(data=df, x="Freedom", y="Economy_GDP_per_Capita", hue="Region")

# %% [raw]
# Here we can see the region wise relationship with Economy_GDP_per_Capita.

# %%
plt.figure(figsize=(8,6), facecolor='pink')
ax = sns.barplot(x='Region',y='Standard_Error',data=df,palette="Blues_d")
ax.set_xticklabels(ax.get_xticklabels(), horizontalalignment='right', rotation=45)
plt.show()

# %% [raw]
# This plot will show the variation in the 'Standard_Error' values across different regions.

# %%
# General statistical description of Categorical variables
df.describe(include=['object'])
# Out:
#             Country              Region
# count           158                 158
# unique          158                  10
# top     Switzerland  Sub-Saharan Africa
# freq              1                  40

# %%
# Stattistical summary of numerical columns
df.describe()
# Out:
#        Happiness_Rank  Happiness_Score  Standard_Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy_GDP_per_Capita      Family  Health_Life_Expectancy   \
# count              158.000000  158.000000               158.000000
# mean                 0.846137    0.991046                 0.630259
# std                  0.403121    0.272369                 0.247078
# min                  0.000000    0.000000                 0.000000
# 25%                  0.545808    0.856823                 0.439185
# ...

# %% [markdown]
# **Key Observations:**
#
#
# 1. The counts of all coulmns are same which means there are no missing values in the dataset.
#
#
# 2. The mean is equal to median (50% percentile) in columns(Happiness_Rank, Happiness_Score, Standard_Error,                        Health_Life_Expectancy, Freedom, Trust_Government_Corruption and Dystopia_Residual), which means the data is a symmetric        distribution, but not always the case. But in few columns : the median(50%) value is greater than the mean, which means          the data is skewed to left in this column.
#
#
# 3. There is a large differences between 75% and max in column (Happiness_Rank), hence there is outliers persent in the data.
#
#
# 4. We can also notice the Standard deviation, min, 25% percentile values from this describe method.

# %%
#'Multivariant anlysis'
sns.pairplot(df)

# %% [raw]
# --> A particular cell value signifies the level of correlation between two variables.
#
# --> The presence of histograms along the diagonal of the pairplot and the purpose of using histograms to represent variable         distributions.

# %%
corr = df.corr()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True)
plt.show()

# %%
df1 = df[df.columns[3:]]
df1.head()
# Out:
#    Happiness_Score  Standard_Error  Economy_GDP_per_Capita   Family  \
# 0            7.587         0.03411                 1.39651  1.34951
# 1            7.561         0.04884                 1.30232  1.40223
# 2            7.527         0.03328                 1.32548  1.36058
# 3            7.522         0.03880                 1.45900  1.33095
# 4            7.427         0.03553                 1.32629  1.32261
#
#    Health_Life_Expectancy   Freedom  Trust_Government_Corruption  Generosity  \
# 0                  0.94143  0.66557                      0.41978     0.29678
# 1                  0.94784  0.62877                      0.14145     0.43630
# 2                  0.87464  0.64938                      0.48357     0.34139
# 3                  0.88521  0.66973                      0.36503     0.34699
# 4                  0.90563  0.63297                      0.32957     0.45811
#
#    Dystopia_Residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# ...

# %%
df1.shape
# Out:
# (158, 9)

# %%
X = df1.drop(columns=['Happiness_Score'])

Y = df1['Happiness_Score']

# %%
plt.figure(figsize=(20,25), facecolor='pink')
plotnumber=1
for column in df1:
    if plotnumber <=9:
        ax =plt.subplot(3,3,plotnumber)
        sns.distplot(df1[column], color = 'b')
        plt.xlabel(column,fontsize=30)
    plotnumber+=1
plt.show()

# %%
df.skew()
# Out:
# Happiness_Rank                 0.000418
# Happiness_Score                0.097769
# Standard_Error                 1.983439
# Economy_GDP_per_Capita        -0.317575
# Family                        -1.006893
# Health_Life_Expectancy        -0.705328
# Freedom                       -0.413462
# Trust_Government_Corruption    1.385463
# Generosity                     1.001961
# Dystopia_Residual             -0.238911
# dtype: float64

# %%
from scipy.stats import boxcox

# %%
df['Standard_Error']= boxcox(df['Standard_Error'],0)

# %%
df.skew()
# Out:
# Happiness_Rank                 0.000418
# Happiness_Score                0.097769
# Standard_Error                 0.484623
# Economy_GDP_per_Capita        -0.317575
# Family                        -1.006893
# Health_Life_Expectancy        -0.705328
# Freedom                       -0.413462
# Trust_Government_Corruption    1.385463
# Generosity                     1.001961
# Dystopia_Residual             -0.238911
# dtype: float64

# %%
df['Trust_Government_Corruption']=boxcox(df['Trust_Government_Corruption'],0)

# %%
df.skew()
# Out:
# Happiness_Rank                 0.000418
# Happiness_Score                0.097769
# Standard_Error                 0.484623
# Economy_GDP_per_Capita        -0.317575
# Family                        -1.006893
# Health_Life_Expectancy        -0.705328
# Freedom                       -0.413462
# Trust_Government_Corruption         NaN
# Generosity                     1.001961
# Dystopia_Residual             -0.238911
# dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif =pd.DataFrame()
vif['vif']= [variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
vif['Features'] = X.columns

vif
# Out:
#          vif                     Features
# 0   7.166167               Standard_Error
# 1  21.759914       Economy_GDP_per_Capita
# 2  25.636995                       Family
# 3  23.090959      Health_Life_Expectancy
# 4  15.880880                      Freedom
# 5   3.497600  Trust_Government_Corruption
# 6   5.600094                   Generosity
# 7  12.574726            Dystopia_Residual

# %%
plt.figure(figsize=(20,25), facecolor='green')
plotnumber=1
for column in df1:
    if plotnumber <=9:
        ax =plt.subplot(3,3,plotnumber)
        sns.histplot(df1[column], palette = 'Rainbow')
        plt.xlabel(column,fontsize=30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
A = df.sort_values(by= 'Happiness_Score', ascending = False ).head(10)
A
# Out:
#        Country                     Region  Happiness_Rank  Happiness_Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard_Error  Economy_GDP_per_Capita   Family  Health_Life_Expectancy   \
# ...

# %%
B= df.sort_values(by = 'Happiness_Score', ascending=True).head(10)
B
# Out:
#           Country                           Region  Happiness_Rank  \
# 157          Togo               Sub-Saharan Africa             158
# 156       Burundi               Sub-Saharan Africa             157
# 155         Syria  Middle East and Northern Africa             156
# 154         Benin               Sub-Saharan Africa             155
# 153        Rwanda               Sub-Saharan Africa             154
# 152   Afghanistan                    Southern Asia             153
# 151  Burkina Faso               Sub-Saharan Africa             152
# 150   Ivory Coast               Sub-Saharan Africa             151
# 149        Guinea               Sub-Saharan Africa             150
# 148          Chad               Sub-Saharan Africa             149
#
#      Happiness_Score  Standard_Error  Economy_GDP_per_Capita   Family  \
# 157            2.839       -2.699041                 0.20868  0.13995
# 156            2.905       -2.446686                 0.01530  0.41587
# ...

# %%
Grp_region=df.groupby('Region')
Grp_region['Happiness_Score'].describe().sort_values(by='mean', ascending =True).head(10)
# Out:
#                                  count      mean       std    min      25%  \
# Region
# Sub-Saharan Africa                40.0  4.202800  0.609557  2.839  3.75600
# Southern Asia                      7.0  4.580857  0.570526  3.575  4.39250
# Southeastern Asia                  9.0  5.317444  0.950020  3.819  4.87600
# Central and Eastern Europe        29.0  5.332931  0.570446  4.218  4.95900
# Middle East and Northern Africa   20.0  5.406900  1.101382  3.006  4.70775
# Eastern Asia                       6.0  5.626167  0.554053  4.874  5.22350
# Latin America and Caribbean       22.0  6.144682  0.728560  4.518  5.84050
# Western Europe                    21.0  6.689619  0.824582  4.857  6.30200
# North America                      2.0  7.273000  0.217789  7.119  7.19600
# Australia and New Zealand          2.0  7.285000  0.001414  7.284  7.28450
#
#                                    50%      75%    max
# Region
# Sub-Saharan Africa               4.272  4.58075  5.477
# ...

# %%
df1.plot(kind = 'box',subplots = True, layout= (3,4))
plt.tight_layout()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.33, random_state=43)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (105, 8)
# Training target vector size: (105,)
# Test feature matrix size: (53, 8)
# Test target vector size: (53,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,200):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.33, random_state=i)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best accuracy is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.999999955318454 on Random_state 148

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.33, random_state=148)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('Predicted result price:\n', y_pred)
print('\n')
print('actual price\n',Y_test)
# Out:
# Predicted result price:
#  [4.19435462 4.51783157 6.8101893  5.01306089 4.50719926 4.27067703
#  7.5270131  6.78615758 6.79779076 4.89757075 4.076767   6.75010255
#  3.89660894 3.66726541 7.22558074 5.832712   5.98708888 4.85766282
#  5.87825745 4.56464368 7.28598539 6.93731965 5.70878587 6.66962698
#  6.29813718 2.83894048 3.68090087 5.05722719 3.34000395 3.67770984
#  3.98885057 5.8282158  3.93080562 4.86720704 7.19975796 4.30691724
#  7.18722252 3.00638777 7.27763061 4.8759534  6.26918541 5.47698043
#  4.97110319 7.52214256 3.84497171 6.41123729 6.12268394 4.33217718
#  4.9487715  4.67744738 5.75859498 6.98252597 5.39865551]
#
#
# actual price
#  134    4.194
# 118    4.518
# 22     6.810
# 91     5.013
# 122    4.507
# 131    4.271
# 2      7.527
# 24     6.786
# 23     6.798
# 96     4.898
# 135    4.077
# 25     6.750
# 142    3.896
# 148    3.667
# 11     7.226
# 55     5.833
# 45     5.987
# 101    4.857
# 52     5.878
# 116    4.565
# 8      7.286
# 18     6.937
# ...

# %%
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred))
# Out:
#  Error :
# Mean absolute error : 0.0002330664940883476
# Mean squared error : 7.582563994814939e-08
# Root Mean Squared Error: 0.00027536455826440226
#
#
#  R2 Score :
# 0.999999955318454

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

# %%
rf = RandomForestRegressor(n_estimators = 100 )
svr=SVR()
dtc = DecisionTreeRegressor()
ad=AdaBoostRegressor()

model = [rf,svr,dtc,ad]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
                                            
    print(' Error of :')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
   

    print(' R2 Score :')
    print(r2_score(Y_test,y_pred)) 
    print('\n')
# Out:
#  Error of :
# Mean absolute error : 0.3982803773584911
# Mean squared error : 0.26402431256981157
# Root Mean Squared Error: 0.5138329617393298
#  R2 Score :
# 0.8444191901300879
#
#
#  Error of :
# Mean absolute error : 0.13984156840268566
# Mean squared error : 0.05213341416923218
# Root Mean Squared Error: 0.22832742754481378
#  R2 Score :
# 0.9692795003657549
#
#
#  Error of :
# Mean absolute error : 0.4812830188679246
# Mean squared error : 0.35514350943396233
# Root Mean Squared Error: 0.5959391826637701
#  R2 Score :
# 0.7907256559822731
#
#
#  Error of :
# Mean absolute error : 0.45688764527167347
# Mean squared error : 0.34378193350419395
# Root Mean Squared Error: 0.5863292023293688
#  R2 Score :
# 0.7974206575423453

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(lin_reg, X, Y, cv = 5)
print('Cross Validation Score :')
print("Score :" ,score)
print("Mean Score :",score.mean())
print("Std deviation :",score.std())
# Out:
# Cross Validation Score :
# Score : [0.99999945 0.99999834 0.99999836 0.99999535 0.99999943]
# Mean Score : 0.9999981871007761
# Std deviation : 1.4991023001111373e-06

# %%
import joblib
joblib.dump(lin_reg,'lin_reg.obj')
# Out:
# ['lin_reg.obj']
